# %%
import os
import sys
from pathlib import Path

project_root = os.path.abspath(os.path.join(os.getcwd(),".."))
sys.path.append(project_root)

# %%
pr = (Path(os.getcwd())/'..').resolve()
current_file = os.path.join(os.getcwd(),'converters_explore.ipynb')

# %%
pr.resolve()
# Out:
# PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks')

# %%
p, n = os.path.split(current_file)
b, e = os.path.splitext(n)
e
# Out:
# '.ipynb'

# %%
cf = pr/'etcTests/converters_explore.ipynb'

# %%
cf
# Out:
# PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/etcTests/converters_explore.ipynb')

# %%
cf.is_file()
# Out:
# True

# %%
for i, e in enumerate([1,2,3,4,5]):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
cf.parent
# Out:
# PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/etcTests')

# %%
sorted(pr.glob("*.ipynb"))
# Out:
# [PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/260204.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/260205.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/260206.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/260209.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/Untitled.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/Untitled1.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/Untitled2.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/banana.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/histogram_summed.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/spectra_current_thrsh.ipynb'),
#  PosixPath('/home/oscar/Projects/SIPHRA_Testing/noteboks/spectrum_plotter.ipynb')]

# %%
from tqdm import tqdm
from time import sleep

with tqdm(total=100) as pbar:
    for i in range(10):
        sleep(0.1)
        pbar.update(10)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 99.06it/s]
